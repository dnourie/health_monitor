# %% [markdown]
# # Exploratory Analysis
#
# Questions from the data that I want to answer:
# - Does poor sleep precede migraines?
# - Are ketones above 1.5 associated with better energy?
# - Does glucose correlate with headaches?
# - Are waking headaches becoming more common?
# - Does weather seem related?
# - Are migraines clustered after multiple nights of poor sleep?

# %%
import pandas
import csv

with open('file.csv', mode='r', newline='') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)  # Each row is a list of strings

# %%
df.groupby("migraine_yes_no")[
    ["glucose_mg_dl",
     "ketones_mmol_l",
     "energy_1_to_10",
     "headache_severity_0_to_10"]
].mean()
